# %%
from sdv.demo import load_tabular_demo

from sdv.tabular import GaussianCopula

real_data = load_tabular_demo('student_placements')

model = GaussianCopula()

model.fit(real_data)

synthetic_data = model.sample()
# Out:
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\scipy\stats\_continuous_distns.py:5003: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\scipy\stats\_distn_infrastructure.py:2494: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\scipy\stats\_continuous_distns.py:621: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)

# %%
real_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17264      M        67.00      91.00  Commerce        58.00
# 1       17265      M        79.33      78.33   Science        77.48
# 2       17266      M        65.00      68.00      Arts        64.00
# 3       17267      M        56.00      52.00   Science        52.00
# 4       17268      M        85.80      73.60  Commerce        73.30
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0                55.0   Mkt&HR
# 1    Sci&Tech             True                 1                86.5  Mkt&Fin
# 2   Comm&Mgmt            False                 0                75.0  Mkt&Fin
# 3    Sci&Tech            False                 0                66.0   Mkt&HR
# 4   Comm&Mgmt            False                 0                96.8  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date  duration
# 0     58.80  27000.0    True 2020-07-23 2020-10-12       3.0
# 1     66.28  20000.0    True 2020-01-11 2020-04-09       3.0
# 2     57.80  25000.0    True 2020-01-26 2020-07-13       6.0
# 3     59.43      NaN   False        NaT        NaT       NaN
# 4     55.50  42500.0    True 2020-07-04 2020-09-27       3.0

# %%
synthetic_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17340      M        51.71      50.94   Science        60.24
# 1       17448      M        59.52      61.54   Science        60.77
# 2       17302      F        54.04      72.95  Commerce        61.22
# 3       17445      M        53.08      42.19   Science        63.02
# 4       17337      M        57.54      40.37   Science        64.43
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0               67.47   Mkt&HR
# 1      Others            False                 1               95.76   Mkt&HR
# 2    Sci&Tech            False                 1               81.06  Mkt&Fin
# 3   Comm&Mgmt            False                 0               87.94   Mkt&HR
# 4    Sci&Tech            False                 1               76.20   Mkt&HR
#
#    mba_perc   salary  placed start_date   end_date  duration
# 0     59.31      NaN   False        NaT        NaT       NaN
# 1     60.74      NaN   False        NaT        NaT       NaN
# 2     59.69  23200.0    True 2020-04-21 2020-10-12       7.0
# 3     58.26      NaN   False        NaT        NaT       NaN
# 4     65.40      NaN   False        NaT        NaT       NaN

# %%
from sdv.evaluation import evaluate
evaluate(synthetic_data, real_data)
# Out:
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\pandas\core\frame.py:3093: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
# 0.5615188029824564

# %%
evaluate(synthetic_data, real_data, aggregate=False)
# Out:
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sklearn\mixture\_base.py:265: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn('Initialization %d did not converge. '
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_data[pd.isnull(real_data)] = 0.0
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\pandas\core\frame.py:3093: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(-key, value, inplace=True)
# D:\appRoute\Miniconda3\envs\ctgan043\lib\site-packages\sdmetrics\column_pairs\statistical\kl_divergence.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   synthetic_data[pd.isnull(synthetic_data)] = 0.0
#                     metric                                     name  \
# 0          BNLogLikelihood           BayesianNetwork Log Likelihood
# 1        LogisticDetection             LogisticRegression Detection
# 2             SVCDetection                            SVC Detection
# 11         GMLogLikelihood           GaussianMixture Log Likelihood
# 12                  CSTest                              Chi-Squared
# 13                  KSTest  Inverted Kolmogorov-Smirnov D statistic
# 14          KSTestExtended  Inverted Kolmogorov-Smirnov D statistic
# 27  ContinuousKLDivergence   Continuous Kullback–Leibler Divergence
# 28    DiscreteKLDivergence     Discrete Kullback–Leibler Divergence
#
#     raw_score  normalized_score  min_value  max_value      goal
# 0   -3.845644      2.137263e-02       -inf        0.0  MAXIMIZE
# 1    0.454896      4.548955e-01        0.0        1.0  MAXIMIZE
# 2    0.461677      4.616770e-01        0.0        1.0  MAXIMIZE
# 11 -38.665719      1.613212e-17       -inf        inf  MAXIMIZE
# 12   0.881816      8.818161e-01        0.0        1.0  MAXIMIZE
# 13   0.915245      9.152455e-01        0.0        1.0  MAXIMIZE
# 14   0.908527      9.085271e-01        0.0        1.0  MAXIMIZE
# 27   0.487982      4.879824e-01        0.0        1.0  MAXIMIZE
# 28   0.876371      8.763711e-01        0.0        1.0  MAXIMIZE

# %%
evaluate(synthetic_data, real_data, metrics=['CSTest', 'KSTest'])
# Out:
# 0.8985308066364119

# %%
evaluate(synthetic_data, real_data, metrics=['CSTest', 'KSTest'], aggregate=False)
# Out:
#    metric                                     name  raw_score  \
# 0  CSTest                              Chi-Squared   0.881816
# 1  KSTest  Inverted Kolmogorov-Smirnov D statistic   0.915245
#
#    normalized_score  min_value  max_value      goal
# 0          0.881816        0.0        1.0  MAXIMIZE
# 1          0.915245        0.0        1.0  MAXIMIZE
